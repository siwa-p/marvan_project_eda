# %%
import pandas as pd
import glob

# %%
csv_files = glob.glob('../data/*.csv')
df_dict = {k: pd.read_csv(k) for k in csv_files}
i=3
filename = csv_files[i].split('/')[-1].split('.')[0]
df = df_dict[csv_files[i]]

# %%
print(csv_files,filename)
# Out:
# ['../data/us-deathcounts.csv', '../data/uk-covcasebyday.csv', '../data/ca-antibody.csv', '../data/ca-rapidtestdemand.csv'] ca-rapidtestdemand

# %%
df.head()
# Out:
#   REF_DATE     GEO           DGUID  \
# 0  2022-01  Canada  2016A000011124
# 1  2022-01  Canada  2016A000011124
# 2  2022-01  Canada  2016A000011124
# 3  2022-01  Canada  2016A000011124
# 4  2022-01  Canada  2016A000011124
#
#   North American Industry Classification System (NAICS)  \
# 0                                     All industries
# 1                                     All industries
# 2                                     All industries
# 3                                     All industries
# 4                                     All industries
#
#            COVID-19 rapid test kits demand and usage      UOM  UOM_ID  \
# 0  Percent of businesses that used COVID-19 rapid...  Percent     239
# 1  Percent of businesses that did not use COVID-1...  Percent     239
# 2  Percent of businesses for which use of COVID-1...  Percent     239
# 3  Average percent of on-site employees tested us...  Percent     239
# 4  Percent of businesses that don’t know the perc...  Percent     239
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19152 entries, 0 to 19151
# Data columns (total 16 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   REF_DATE                                               19152 non-null  object
#  1   GEO                                                    19152 non-null  object
#  2   DGUID                                                  16758 non-null  object
#  3   North American Industry Classification System (NAICS)  19152 non-null  object
#  4   COVID-19 rapid test kits demand and usage              19152 non-null  object
#  5   UOM                                                    19152 non-null  object
#  6   UOM_ID                                                 19152 non-null  int64
#  7   SCALAR_FACTOR                                          19152 non-null  object
# ...

# %%
df.describe()
# Out:
#         UOM_ID  SCALAR_ID        VALUE  SYMBOL  TERMINATED      DECIMALS
# count  19152.0    19152.0  4437.000000     0.0         0.0  19152.000000
# mean     239.0        0.0    57.398907     NaN         NaN      1.396512
# std        0.0        0.0    36.074985     NaN         NaN      0.918053
# min      239.0        0.0     0.000000     NaN         NaN      0.000000
# 25%      239.0        0.0    26.990000     NaN         NaN      0.000000
# 50%      239.0        0.0    62.720000     NaN         NaN      2.000000
# 75%      239.0        0.0    94.700000     NaN         NaN      2.000000
# max      239.0        0.0   100.000000     NaN         NaN      2.000000

# %%
non_numerical_columns = df.select_dtypes(include=['object']).columns.tolist()

# %%
df['SCALAR_FACTOR'].unique()
# Out:
# array(['units'], dtype=object)

# %%
df['SCALAR_ID'].unique()
# Out:
# array([0])

# %%
df[non_numerical_columns]
# Out:
#       REF_DATE          GEO           DGUID  \
# 0      2022-01       Canada  2016A000011124
# 1      2022-01       Canada  2016A000011124
# 2      2022-01       Canada  2016A000011124
# 3      2022-01       Canada  2016A000011124
# 4      2022-01       Canada  2016A000011124
# ...        ...          ...             ...
# 19147  2022-01  Territories      2016A00016
# 19148  2022-01  Territories      2016A00016
# 19149  2022-01  Territories      2016A00016
# 19150  2022-01  Territories      2016A00016
# 19151  2022-01  Territories      2016A00016
#
#       North American Industry Classification System (NAICS)  \
# 0                                         All industries
# 1                                         All industries
# 2                                         All industries
# 3                                         All industries
# 4                                         All industries
# ...                                                  ...
# ...

# %%
for item in non_numerical_columns:
    print(item, df[item].unique())
# Out:
# REF_DATE ['2022-01']
# GEO ['Canada' 'Atlantic Region' 'Quebec' 'Ontario' 'Manitoba and Saskatchewan'
#  'Alberta' 'British Columbia' 'Territories']
# DGUID ['2016A000011124' '2016A00011' '2016A000224' '2016A000235' nan
#  '2016A000248' '2016A000259' '2016A00016']
# North American Industry Classification System (NAICS) ['All industries' 'Agriculture, forestry, fishing and hunting [11]'
#  'Crop production [111]' 'Animal production and aquaculture [112]'
#  'Forestry and logging [113]' 'Fishing, hunting and trapping [114]'
#  'Support activities for agriculture and forestry [115]'
#  'Mining, quarrying, and oil and gas extraction [21]'
#  'Oil and gas extraction [211]'
#  'Mining and quarrying (except oil and gas) [212]'
#  'Support activities for mining, and oil and gas extraction [213]'
#  'Construction [T23]' 'Construction of buildings [236]'
#  'Manufacturing [31-33]' 'Food manufacturing [311]'
#  'Beverage and tobacco product manufacturing [312]' 'Textile mills [313]'
# ...

# %%
df['VECTOR'].nunique()
# Out:
# 19152

# %%
df['STATUS'].unique()
# Out:
# array(['B', 'A', 'C', 'D', 'F', 'E', '..'], dtype=object)
